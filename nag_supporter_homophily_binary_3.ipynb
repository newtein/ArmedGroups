# %%
from data_reader import DataReader
import pickle
from supporter_countries import SupportModule
from ideology_and_objective import IdeologicalObjectiveModule
import numpy as np
from ideology_homophily_score import IdeologyHomophillyScore
from get_supporter_homophily_from_nag import SupporterHomophillyFromNAG
import pandas as pd
from get_longevity import LongevityModule

# %%
with open("pickles/long_horizon_list.pickle", "rb") as f:
    long_horizon_list = pickle.load(f)
    
with open("pickles/short_horizon_list.pickle", "rb") as f:
    short_horizon_list = pickle.load(f)

# %%
df = DataReader().get_pandas_df()
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3337: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
sup_obj = SupportModule()
homo_obj = SupporterHomophillyFromNAG()
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3417: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
def get_score(nagcode):
    ideology, nonideology = 0, 0
    support_list = sup_obj.get_supporter_from_NAGcode(nagcode)
    ideology_likelihood, nonideology_likelihood = [], []
    for support_code in support_list:
        info = homo_obj.get_binary_supporter_info(support_code)
        predominant_ideology = info.get('predominant_ideology')
        likelihood = info.get('likelihood')
        if predominant_ideology == 'ideology':
            ideology += 1
            ideology_likelihood.append(likelihood)
        elif predominant_ideology == 'nonideology':
            nonideology += 1
            nonideology_likelihood.append(likelihood)
    data = {"NAGcode": nagcode, "num_of_supporters": len(support_list),
           "ideology": ideology, "nonideology": nonideology,
           "ideology_likelihood":np.median(ideology_likelihood),
            "nonideology_likelihood":np.median(nonideology_likelihood)}
    return data

columns= ["NAGcode", "num_of_supporters", "ideology","nonideology",
         "ideology_likelihood","nonideology_likelihood"]
homophily_df = pd.DataFrame(columns=columns)
ideologies = {'ethno_nationalist', 'religious', 'leftist'}
for nagcode in df['NAGcode_1'].unique():
    data = get_score(nagcode)
    t_df = pd.DataFrame(data, index=[0])
    homophily_df = homophily_df.append(t_df)
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ...

# %%
columns= ["NAGcode", "num_of_supporters", "ideology","nonideology",
         "ideology_likelihood","nonideology_likelihood"]
long_homophily_df = pd.DataFrame(columns=columns)
ideologies = {'ethno_nationalist', 'religious', 'leftist'}
for nagcode in long_horizon_list:
    data = get_score(nagcode)
    t_df = pd.DataFrame(data, index=[0])
    long_homophily_df = long_homophily_df.append(t_df)
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ...

# %%
long_homophily_df[long_homophily_df['num_of_supporters']>0].mean()
# Out:
# NAGcode                   223.635514
# num_of_supporters           2.000000
# ideology                    1.822430
# nonideology                 0.093458
# ideology_likelihood         0.865761
# nonideology_likelihood      0.675000
# dtype: float64

# %%
long_homophily_df[long_homophily_df['num_of_supporters']>0].median()
# Out:
# NAGcode                   183.000000
# num_of_supporters           1.000000
# ideology                    1.000000
# nonideology                 0.000000
# ideology_likelihood         0.875000
# nonideology_likelihood      0.666667
# dtype: float64

# %%
long_homophily_df[long_homophily_df['num_of_supporters']>0].count()
# Out:
# NAGcode                   107
# num_of_supporters         107
# ideology                  107
# nonideology               107
# ideology_likelihood       102
# nonideology_likelihood      9
# dtype: int64

# %%
columns= ["NAGcode", "num_of_supporters", "ideology","nonideology",
         "ideology_likelihood","nonideology_likelihood"]
short_homophily_df = pd.DataFrame(columns=columns)
ideologies = {'ethno_nationalist', 'religious', 'leftist'}
for nagcode in short_horizon_list:
    data = get_score(nagcode)
    t_df = pd.DataFrame(data, index=[0])
    short_homophily_df = short_homophily_df.append(t_df)
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# ...

# %%
short_homophily_df[short_homophily_df['num_of_supporters']>0].mean()
# Out:
# NAGcode                   291.614035
# num_of_supporters           2.146199
# ideology                    1.754386
# nonideology                 0.280702
# ideology_likelihood         0.805786
# nonideology_likelihood      0.808586
# dtype: float64

# %%
short_homophily_df[short_homophily_df['num_of_supporters']>0].median()
# Out:
# NAGcode                   301.000000
# num_of_supporters           2.000000
# ideology                    1.000000
# nonideology                 0.000000
# ideology_likelihood         0.821591
# nonideology_likelihood      0.791667
# dtype: float64

# %%
short_homophily_df[short_homophily_df['num_of_supporters']>0].count()
# Out:
# NAGcode                   171
# num_of_supporters         171
# ideology                  171
# nonideology               171
# ideology_likelihood       156
# nonideology_likelihood     33
# dtype: int64

# %%
short_homophily_df.mean()
# Out:
# NAGcode                   304.606707
# num_of_supporters           1.118902
# ideology                    0.914634
# nonideology                 0.146341
# ideology_likelihood         0.805786
# nonideology_likelihood      0.808586
# dtype: float64

# %%
long_homophily_df.mean()
# Out:
# NAGcode                   243.096154
# num_of_supporters           1.028846
# ideology                    0.937500
# nonideology                 0.048077
# ideology_likelihood         0.865761
# nonideology_likelihood      0.675000
# dtype: float64

# %%
short_homophily_df
# Out:
#    NAGcode num_of_supporters ideology nonideology  ideology_likelihood  \
# 0       26                 1        1           0             0.818182
# 0      301                 3        2           0             0.735714
# 0      235                 3        3           0             1.000000
# 0      345                 1        0           1                  NaN
# 0      354                 5        5           0             0.750000
# ..     ...               ...      ...         ...                  ...
# 0      512                 0        0           0                  NaN
# 0      553                14       10           2             0.708333
# 0      500                 0        0           0                  NaN
# 0      566                 0        0           0                  NaN
# 0      539                 1        1           0             0.571429
#
#     nonideology_likelihood
# 0                      NaN
# 0                      NaN
# 0                      NaN
# ...

# %%
ideo_obj = IdeologicalObjectiveModule()
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3417: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
from collections import Counter

def get_nag_count(nag_list):
    temp = []
    for nagcode in nag_list:
        temp.append(ideo_obj.ideology_exists(nagcode))  
    return Counter(temp)

# %%
get_nag_count(short_horizon_list)
# Out:
# Counter({0: 110, 1: 184, -1: 34})

# %%
get_nag_count(long_horizon_list)
# Out:
# Counter({1: 191, 0: 17})

# %%
short_homophily_df['ideology_exists'] = [ideo_obj.ideology_exists(nagcode) for nagcode in short_homophily_df['NAGcode'].unique()]

# %%
short_homophily_df
# Out:
#    NAGcode num_of_supporters ideology nonideology  ideology_likelihood  \
# 0       26                 1        1           0             0.818182
# 0      301                 3        2           0             0.735714
# 0      235                 3        3           0             1.000000
# 0      345                 1        0           1                  NaN
# 0      354                 5        5           0             0.750000
# ..     ...               ...      ...         ...                  ...
# 0      512                 0        0           0                  NaN
# 0      553                14       10           2             0.708333
# 0      500                 0        0           0                  NaN
# 0      566                 0        0           0                  NaN
# 0      539                 1        1           0             0.571429
#
#     nonideology_likelihood  ideology_exists
# 0                      NaN                0
# ...

# %%
long_homophily_df['ideology_exists'] = [ideo_obj.ideology_exists(nagcode) for nagcode in long_homophily_df['NAGcode'].unique()]

# %%
def filter_no_sup(df, supporter, ideology_exists):
    f1 = (df['num_of_supporters']==supporter)
    f2 = (df['ideology_exists']==ideology_exists)
    d = df[f1 & f2].shape[0]
    return d

def filter_sup(df, supporter, ideology_exists):
    f1 = (df['num_of_supporters']>supporter)
    f2 = (df['ideology_exists']==ideology_exists)
    d = df[f1 & f2].shape[0]
    return d

def info(df):
    t= {}
    d = filter_no_sup(df, 0, 0)
    t['no_sup_no_ideology'] = d
    d = filter_no_sup(df, 0, 1)
    t['no_sup_ideology'] = d
    d = filter_sup(df, 0, 0)
    t['sup_no_ideology'] = d
    d = filter_sup(df, 0, 1)
    t['sup_ideology'] = d
    return t

# %%
info(short_homophily_df)
# Out:
# {'no_sup_no_ideology': 50,
#  'no_sup_ideology': 82,
#  'sup_no_ideology': 60,
#  'sup_ideology': 102}

# %%
info(long_homophily_df)
# Out:
# {'no_sup_no_ideology': 7,
#  'no_sup_ideology': 94,
#  'sup_no_ideology': 10,
#  'sup_ideology': 97}

# %%
def avg_sup(df, ideology_exists):
    f1 = df['ideology_exists']==ideology_exists
    mean = df[f1]['num_of_supporters'].mean()
    median = df[f1]['num_of_supporters'].median()
    n = df[f1]['num_of_supporters'].sum()
    return mean, median, n

def info2(df):
    t= {}
    d = avg_sup(df, 0)
    t['no_ideology_avg_sup'] = d
    d = avg_sup(df, 1)
    t['ideology_avg_sup'] = d
    return t

# %%
info2(short_homophily_df)
# Out:
# {'no_ideology_avg_sup': (1.0636363636363637, 1.0, 117),
#  'ideology_avg_sup': (1.201086956521739, 1.0, 221)}

# %%
info2(long_homophily_df)
# Out:
# {'no_ideology_avg_sup': (0.9411764705882353, 1.0, 16),
#  'ideology_avg_sup': (1.036649214659686, 1.0, 198)}

# %%
long_obj = LongevityModule()
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3417: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
short_homophily_df['lifespan'] = [long_obj.calculate_longevity(nagcode)[0] for nagcode in short_homophily_df['NAGcode'].unique()]
long_homophily_df['lifespan'] = [long_obj.calculate_longevity(nagcode)[0] for nagcode in long_homophily_df['NAGcode'].unique()]

# %%
short_homophily_df
# Out:
#    NAGcode num_of_supporters ideology nonideology  ideology_likelihood  \
# 0       26                 1        1           0             0.818182
# 0      301                 3        2           0             0.735714
# 0      235                 3        3           0             1.000000
# 0      345                 1        0           1                  NaN
# 0      354                 5        5           0             0.750000
# ..     ...               ...      ...         ...                  ...
# 0      512                 0        0           0                  NaN
# 0      553                14       10           2             0.708333
# 0      500                 0        0           0                  NaN
# 0      566                 0        0           0                  NaN
# 0      539                 1        1           0             0.571429
#
#     nonideology_likelihood  ideology_exists  lifespan
# 0                      NaN                0        32
# ...

# %%
def avg_lifespan(df, ideology_exists):
    f1 = df['ideology_exists']==ideology_exists
    mean = df[f1]['lifespan'].mean()
    std = df[f1]['lifespan'].std()
    return mean, std

def info3(df):
    t= {}
    d = avg_lifespan(df, 0)
    t['no_ideology_avg_lifespan'] = d
    d = avg_lifespan(df, 1)
    t['ideology_avg_lifespan'] = d
    return t

# %%
info3(short_homophily_df)
# Out:
# {'no_ideology_avg_lifespan': (5.372727272727273, 5.541932049598646),
#  'ideology_avg_lifespan': (14.51086956521739, 15.304554531369375)}

# %%
info3(long_homophily_df)
# Out:
# {'no_ideology_avg_lifespan': (13.294117647058824, 14.039073624541404),
#  'ideology_avg_lifespan': (15.963350785340314, 14.532131994036233)}

# %%
short_homophily_df
# Out:
#    NAGcode num_of_supporters ideology nonideology  ideology_likelihood  \
# 0       26                 1        1           0             0.818182
# 0      301                 3        2           0             0.735714
# 0      235                 3        3           0             1.000000
# 0      345                 1        0           1                  NaN
# 0      354                 5        5           0             0.750000
# ..     ...               ...      ...         ...                  ...
# 0      512                 0        0           0                  NaN
# 0      553                14       10           2             0.708333
# 0      500                 0        0           0                  NaN
# 0      566                 0        0           0                  NaN
# 0      539                 1        1           0             0.571429
#
#     nonideology_likelihood  ideology_exists  lifespan
# 0                      NaN                0        32
# ...

# %%
def avg_homo(df, ideology_exists):
    # f1 = (df['ideology_exists']==ideology_exists) & (df['num_of_supporters']>0)
    f1 = df['ideology_exists']==ideology_exists

    a = df[f1]['ideology'].sum()
    b = df[f1]['nonideology'].sum()
    return a/(a+b), b/(a+b) 

def info4(df):
    t= {}
    d = avg_homo(df, 0)
    t['no_ideology_sup_per'] = d
    d = avg_homo(df, 1)
    t['ideology_sup_per'] = d
    return t

# %%
info4(short_homophily_df)
# Out:
# {'no_ideology_sup_per': (0.6576576576576577, 0.34234234234234234),
#  'ideology_sup_per': (0.9722222222222222, 0.027777777777777776)}

# %%
info4(long_homophily_df)
# Out:
# {'no_ideology_sup_per': (0.5833333333333334, 0.4166666666666667),
#  'ideology_sup_per': (0.9740932642487047, 0.025906735751295335)}

# %%
def avg_lifespan(df, ideology_exists):
    f1 = df['ideology_exists']==ideology_exists
    mean = df[f1]['lifespan'].mean()
    std = df[f1]['lifespan'].std()
    return mean, std

def info3(df):
    t= {}
    d = avg_lifespan(df, 0)
    t['no_ideology_avg_lifespan'] = d
    d = avg_lifespan(df, 1)
    t['ideology_avg_lifespan'] = d
    return t

# %%
from get_domestic_support import DSupModule

# %%
dup_obj = DSupModule()
# Out:
# c:\users\administrator\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3417: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
short_homophily_df['domsup'] = [dup_obj.get(nagcode)[0] for nagcode in short_homophily_df['NAGcode'].unique()]
long_homophily_df['domsup'] = [dup_obj.get(nagcode)[0] for nagcode in long_homophily_df['NAGcode'].unique()]

# %%
def domsup(df, ideology_exists, domsup):
    f1 = (df['ideology_exists']==ideology_exists) & (df['domsup'] == domsup)
    n = df[f1].shape[0]
    return n

def info5(df):
    t= {}
    d = domsup(df, 0, 0)
    t['no_ideology_no_domsup'] = d
    d = domsup(df, 0, 1)
    t['no_ideology_domsup'] = d
    d = domsup(df, 1, 0)
    t['ideology_no_domsup'] = d
    d = domsup(df, 1, 1)
    t['ideology_domsup'] = d
    return t

# %%
info5(short_homophily_df)
# Out:
# {'no_ideology_no_domsup': 100,
#  'no_ideology_domsup': 10,
#  'ideology_no_domsup': 148,
#  'ideology_domsup': 36}

# %%
info5(long_homophily_df)
# Out:
# {'no_ideology_no_domsup': 14,
#  'no_ideology_domsup': 3,
#  'ideology_no_domsup': 137,
#  'ideology_domsup': 54}

# %%
short_homophily_df['ppd'] = [dup_obj.get_political_party(nagcode)[0] for nagcode in short_homophily_df['NAGcode'].unique()]
long_homophily_df['ppd'] = [dup_obj.get_political_party(nagcode)[0] for nagcode in long_homophily_df['NAGcode'].unique()]

# %%
def ppd(df, ideology_exists, ppd):
    f1 = (df['ideology_exists']==ideology_exists) & (df['ppd'] == ppd)
    n = df[f1].shape[0]
    return n

def info6(df):
    t= {}
    d = ppd(df, 0, 0)
    t['no_ideology_no_ppd'] = d
    d = ppd(df, 0, 1)
    t['no_ideology_ppd'] = d
    d = ppd(df, 1, 0)
    t['ideology_no_ppd'] = d
    d = ppd(df, 1, 1)
    t['ideology_ppd'] = d
    return t

# %%
info6(short_homophily_df)
# Out:
# {'no_ideology_no_ppd': 102,
#  'no_ideology_ppd': 8,
#  'ideology_no_ppd': 151,
#  'ideology_ppd': 33}

# %%
info6(long_homophily_df)
# Out:
# {'no_ideology_no_ppd': 14,
#  'no_ideology_ppd': 3,
#  'ideology_no_ppd': 160,
#  'ideology_ppd': 31}
